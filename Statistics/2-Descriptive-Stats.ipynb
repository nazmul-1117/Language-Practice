# %% [markdown]
# #Descriptive Statistics
# ```
# Descriptive Statistics stands for describe, summarise the data like mean, median, mode, variance, std. deviation
# ```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Titanic-Dataset.csv')
bckp = data.copy()

# %%
data.shape
# Out:
# (891, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Descriptive Statistics
# ```
# 1. Measures of Central Tendency
#   1.1 Mean
#   1.2 Median
#   1.3 Mode
# 2. Measures of Variability
#   2.1 Range
#   2.2 Variance
#   2.3 Standard Deviation
# ```

# %% [markdown]
# #1. Measures of Central Tendency
#
#
# ```
# Measures the central of data
# ```

# %% [markdown]
# # 1.1 Mean

# %%
data['Age'].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# # 1.2 Median

# %%
data['Age'].median()
# Out:
# 28.0

# %% [markdown]
# # 1.3 Mode

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Sex'].mode()
# Out:
# 0    male
# Name: Sex, dtype: object

# %% [markdown]
# # 2. Measures of Variability
#
#
# ```
# Describe the spread of data
# ```

# %% [markdown]
# # 2.1 Range

# %%
data['Age'].max() - data['Age'].min()
# Out:
# 79.58

# %% [markdown]
# # 2.2 Variance

# %%
data['Age'].var()
# Out:
# 211.0191247463081

# %% [markdown]
# # 2.3 Standard Deviation

# %%
data['Age'].std()
# Out:
# 14.526497332334044
