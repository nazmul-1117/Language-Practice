# %% [markdown]
# # EDA 1 - Data Cleansing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv('Churn_Modelling_New.csv')
df_cp = df.copy()

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.isnull().sum()>0
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                 True
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary     True
# Exited             False
# dtype: bool

# %% [markdown]
# # Drop Column

# %%
drop_col = df.copy()
# drop_col.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1, inplace=True)
drop_col.dropna(inplace=True, axis=1)

# %%
df.shape, drop_col.shape
# Out:
# ((10000, 14), (10000, 12))

# %%
drop_col.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Tenure  \
# 0          1    15634602  Hargrave          619    France  Female       2
# 1          2    15647311      Hill          608     Spain  Female       1
# 2          3    15619304      Onio          502    France  Female       8
# 3          4    15701354      Boni          699    France  Female       1
# 4          5    15737888  Mitchell          850     Spain  Female       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  Exited
# 0       0.00              1          1               1       1
# 1   83807.86              1          0               1       0
# 2  159660.80              3          1               0       1
# 3       0.00              2          0               0       0
# 4  125510.82              1          1               1       0

# %% [markdown]
# # Drop Rows

# %%
drop_row = df.copy()
drop_row.dropna(inplace=True, axis=0)

# %%
df.shape, drop_row.shape
# Out:
# ((10000, 14), (9935, 14))

# %% [markdown]
# # Fill Data with mean

# %%
fill_mean = df.copy()
fill_mean = fill_mean.select_dtypes(['int64', 'float64'])
y = fill_mean.isnull().any()
num_list = y[y].index
num_list

# fill_mean.fillna(fill_mean.mean(), inplace=True)
# Out:
# Index(['Age', 'EstimatedSalary'], dtype='object')

# %%
z = fill_mean.fillna(fill_mean.mean())
z[num_list]
# Out:
#        Age  EstimatedSalary
# 0     42.0        101348.88
# 1     41.0        112542.58
# 2     42.0        113931.57
# 3     39.0         93826.63
# 4     43.0         79084.10
# ...    ...              ...
# 9995  39.0         96270.64
# 9996  35.0        101699.77
# 9997  36.0         42085.58
# 9998  42.0         92888.52
# 9999  28.0         38190.78
#
# [10000 rows x 2 columns]

# %%
z.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # Fill data with median

# %%
fill_mean = df.copy()
fill_mean = fill_mean.select_dtypes(['int64', 'float64'])
y = fill_mean.isnull().any()
num_list = y[y].index
num_list
# Out:
# Index(['Age', 'EstimatedSalary'], dtype='object')

# %%
fill_mean.fillna(fill_mean.median(), inplace=True)

# %%
fill_mean.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64
